# %%
import pandas as pd
import numpy as np

# %%
URL = r"D:\UM internship\Bird Strike\bird_strike_URMproject.csv"

bird_strike2 = pd.read_csv(URL)

# %%
bird_strike2.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
bird_strike2
# Out:
#                          Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                         LAGUARDIA NY    > 1000 ft            B-737-400
# 1          DALLAS/FORT WORTH INTL ARPT    < 1000 ft                MD-80
# 2                    LAKEFRONT AIRPORT    < 1000 ft                C-500
# 3                  SEATTLE-TACOMA INTL    < 1000 ft            B-737-400
# 4                         NORFOLK INTL    < 1000 ft         CL-RJ100/200
# ...                                ...          ...                  ...
# 25424                  SACRAMENTO INTL    < 1000 ft            B-737-700
# 25425                REDDING MUNICIPAL    > 1000 ft              EMB-120
# 25426                     ORLANDO INTL    < 1000 ft                A-321
# 25427  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft            B-757-200
# 25428     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft            B-737-400
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
bird_strike2[pd.isnull(bird_strike2['Aircraft: Number of engines?'])].head(227)
# Out:
#                           Airport: Name Altitude bin Aircraft: Make/Model  \
# 42        BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 61        BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# 210       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 216            CHARLESTON AFB/INTL ARPT    > 1000 ft                C-17A
# 220       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# ...                                 ...          ...                  ...
# 24957              ELLINGTON FIELD ARPT    < 1000 ft                T-38A
# 25037               JOHN F KENNEDY INTL    < 1000 ft              CRJ-440
# 25062    FORT LAUDERDALE EXECUTIVE ARPT    < 1000 ft            PA-31-350
# 25092                HONOLULU INTL ARPT    < 1000 ft               F/A-18
# 25347  KALAELOA ARPT JOHN RODGERS FIELD    < 1000 ft                DA-40
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
filtered_data = bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'C-17A']
filtered_data
# Out:
#                  Airport: Name Altitude bin Aircraft: Make/Model  \
# 216   CHARLESTON AFB/INTL ARPT    > 1000 ft                C-17A
# 242   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 247   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 297   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 303   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 368   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 375   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 579   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 706   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 755   CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 5014  CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# 6571  CHARLESTON AFB/INTL ARPT    > 1000 ft                C-17A
# 6836  CHARLESTON AFB/INTL ARPT    < 1000 ft                C-17A
# ...

# %%
filtered_data = bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'T-38A']
filtered_data
# Out:
#                        Airport: Name Altitude bin Aircraft: Make/Model  \
# 257          SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 434          SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 4303            ELLINGTON FIELD ARPT    < 1000 ft                T-38A
# 5108         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 5785         SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 5796         SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 5838         SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 5923         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 6093         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 6309   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                T-38A
# 6555         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 6655         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# ...

# %%
filtered_data = bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CRJ-440']
filtered_data
# Out:
#                          Airport: Name Altitude bin Aircraft: Make/Model  \
# 1803   DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 1804                      MEMPHIS INTL    < 1000 ft              CRJ-440
# 2180       CLEVELAND-HOPKINS INTL ARPT    < 1000 ft              CRJ-440
# 2885   DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 2922   DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# ...                                ...          ...                  ...
# 21886        OUTAGAMIE COUNTY REGIONAL    < 1000 ft              CRJ-440
# 22173  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 23646  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 24281                   QUAD CITY ARPT    < 1000 ft              CRJ-440
# 25037              JOHN F KENNEDY INTL    < 1000 ft              CRJ-440
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
filtered_data = bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'PA-31-350']
filtered_data
# Out:
#                         Airport: Name Altitude bin Aircraft: Make/Model  \
# 3804               FRIDAY HARBOR ARPT    < 1000 ft            PA-31-350
# 3861                     KAPALUA ARPT    < 1000 ft            PA-31-350
# 18803       MORRISTOWN MUNICIPAL ARPT    < 1000 ft            PA-31-350
# 20527               TETERBORO AIRPORT    < 1000 ft            PA-31-350
# 23406              KLAMATH FALLS INTL    < 1000 ft            PA-31-350
# 25062  FORT LAUDERDALE EXECUTIVE ARPT    < 1000 ft            PA-31-350
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 3804                  2 to 10                               4
# 3861                  2 to 10                              10
# 18803                       1                               1
# 20527                       1                               1
# 23406                       1                               1
# 25062                       1                               1
#
# ...

# %%
filtered_data = bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'F/A-18']
filtered_data
# Out:
#             Airport: Name Altitude bin Aircraft: Make/Model  \
# 25092  HONOLULU INTL ARPT    < 1000 ft               F/A-18
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 25092                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 25092                     None  2011-10-22                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 25092                           NaN               HAWAIIAN AIR  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 25092          Landing Roll                      None          Small
#
#       Conditions: Sky     Wildlife: Species  \
# 25092        No Cloud  Unknown bird - small
#
#       Pilot warned of birds or wildlife? Cost: Total $  Feet above ground  \
# 25092                                  N             0                0.0
#
# ...

# %%
filtered_data = bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'DA-40']
filtered_data
# Out:
#                           Airport: Name Altitude bin Aircraft: Make/Model  \
# 25347  KALAELOA ARPT JOHN RODGERS FIELD    < 1000 ft                DA-40
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 25347                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 25347                     None  2011-11-30                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 25347                           NaN                   BUSINESS  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 25347                  Taxi                      None          Small
#
#       Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 25347        No Cloud        Zebra dove                                  N
#
#       Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'AT-38B']
# Out:
#                 Airport: Name Altitude bin Aircraft: Make/Model  \
# 237   SHEPPARD AIR FORCE BASE    < 1000 ft               AT-38B
# 5132  SHEPPARD AIR FORCE BASE    > 1000 ft               AT-38B
# 5139  SHEPPARD AIR FORCE BASE    < 1000 ft               AT-38B
# 5930  SHEPPARD AIR FORCE BASE    < 1000 ft               AT-38B
# 6342  SHEPPARD AIR FORCE BASE    < 1000 ft               AT-38B
# 7757  SHEPPARD AIR FORCE BASE    < 1000 ft               AT-38B
# 7831  SHEPPARD AIR FORCE BASE    < 1000 ft               AT-38B
# 7893  SHEPPARD AIR FORCE BASE    > 1000 ft               AT-38B
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 237                  2 to 10                               2
# 5132                       1                               1
# 5139                       1                               1
# 5930                       1                               1
# 6342                       1                               1
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'C-130E']
# Out:
#                           Airport: Name Altitude bin Aircraft: Make/Model  \
# 474  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft               C-130E
#
#     Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 474                 2 to 10                               9
#
#     Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 474                     None  2002-02-01                No damage
#
#      Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 474                           NaN                   MILITARY  ...
#
#     When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 474                 Climb                      Snow         Medium
#
#     Conditions: Sky    Wildlife: Species Pilot warned of birds or wildlife?  \
# 474        Overcast  Unknown bird or bat                                  Y
#
#     Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'A-10A']
# Out:
#                       Airport: Name Altitude bin Aircraft: Make/Model  \
# 477   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                A-10A
# 6104  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                A-10A
# 6774  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                A-10A
# 7067  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                A-10A
# 7190  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                A-10A
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 477                  2 to 10                               4
# 6104                       1                               1
# 6774                       1                               1
# 7067                       1                               1
# 7190                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 477     Precautionary Landing  2002-02-07                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'MISC - OTHER']
# Out:
#                     Airport: Name Altitude bin Aircraft: Make/Model  \
# 2264  LORAIN COUNTY REGIONAL ARPT    < 1000 ft         MISC - OTHER
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 2264                 2 to 10                              10
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 2264                     None  2007-09-09                No damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 2264                           NaN            PRIVATELY OWNED  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 2264              Approach                      None          Small
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 2264      Some Cloud     Mourning dove                                  Y
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# 2264             0               25.0                         0
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'F-16D']
# Out:
#                           Airport: Name Altitude bin Aircraft: Make/Model  \
# 568  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft                F-16D
#
#     Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 568                 2 to 10                               5
#
#     Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 568                     None  2002-07-15                No damage
#
#      Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 568                           NaN                   MILITARY  ...
#
#     When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 568          Take-off run                      None          Small
#
#     Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 568        No Cloud     Mourning dove                                  Y
#
#     Cost: Total $  Feet above ground  Number of people injured  \
# 568             0                0.0                         0
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CESSNA UNKN']
# Out:
#                    Airport: Name Altitude bin Aircraft: Make/Model  \
# 2421            GRAND FORKS INTL    > 1000 ft          CESSNA UNKN
# 5282      WILL ROGERS WORLD ARPT    < 1000 ft          CESSNA UNKN
# 5316           LINCOLN MUNICIPAL    < 1000 ft          CESSNA UNKN
# 9823  WICHITA MID-CONTINENT ARPT    < 1000 ft          CESSNA UNKN
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 2421                 2 to 10                              10
# 5282                       1                               1
# 5316                       1                               1
# 9823                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 2421                     None  2008-02-03            Caused damage
# 5282                     None  2000-08-17                No damage
# 5316                     None  2000-08-25                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CITATION MUSTANG 510']
# Out:
#              Airport: Name Altitude bin  Aircraft: Make/Model  \
# 2796   JOE FOSS FIELD ARPT    < 1000 ft  CITATION MUSTANG 510
# 19707        HOUSTON-HOBBY    < 1000 ft  CITATION MUSTANG 510
# 21541  OAKLAND COUNTY INTL    < 1000 ft  CITATION MUSTANG 510
# 21584        BOB HOPE ARPT    < 1000 ft  CITATION MUSTANG 510
# 21909  HAGERSTOWN REGIONAL    < 1000 ft  CITATION MUSTANG 510
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 2796                  2 to 10                               4
# 19707                       1                               1
# 21541                       1                               1
# 21584                       1                               1
# 21909                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 2796     Precautionary Landing  2009-03-10            Caused damage
# 19707                     None  2009-09-17                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'C-21A']
# Out:
#                 Airport: Name Altitude bin Aircraft: Make/Model  \
# 306  CHARLESTON AFB/INTL ARPT    < 1000 ft                C-21A
# 307  CHARLESTON AFB/INTL ARPT    < 1000 ft                C-21A
#
#     Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 306                 2 to 10                               5
# 307                 2 to 10                               2
#
#     Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 306         Aborted Take-off  2001-07-07                No damage
# 307         Aborted Take-off  2001-07-07                No damage
#
#      Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 306                           NaN                   MILITARY  ...
# 307                           NaN                   MILITARY  ...
#
#     When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 306                 Climb                      None         Medium
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'HAWKER 900']
# Out:
#                       Airport: Name Altitude bin Aircraft: Make/Model  \
# 3489   COLUMBUS MUNICIPAL ARPT (IN)    < 1000 ft           HAWKER 900
# 20398            SARASOTA-BRADENTON    < 1000 ft           HAWKER 900
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 3489                  2 to 10                               3
# 20398                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 3489                      None  2010-07-27                No damage
# 20398    Precautionary Landing  2009-12-06            Caused damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 3489                            NaN                   BUSINESS  ...
# 20398                           NaN                   BUSINESS  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 3489                  Climb                      None          Small
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'BD-700']
# Out:
#                      Airport: Name Altitude bin Aircraft: Make/Model  \
# 3629             ST LOUIS DOWNTOWN    < 1000 ft               BD-700
# 19683      WESTCHESTER COUNTY ARPT    < 1000 ft               BD-700
# 21411           ATLANTIC CITY INTL    < 1000 ft               BD-700
# 22807  WASHINGTON DULLES INTL ARPT    > 1000 ft               BD-700
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 3629                  2 to 10                               8
# 19683                       1                               1
# 21411                       1                               1
# 22807                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 3629          Aborted Take-off  2010-09-08                No damage
# 19683                     None  2009-09-16                No damage
# 21411                     None  2010-07-01                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'B-787-800']
# Out:
#            Airport: Name Altitude bin Aircraft: Make/Model  \
# 4013  KLAMATH FALLS INTL    < 1000 ft            B-787-800
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 4013                 2 to 10                               4
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 4013                     None  2011-07-22                No damage
#
#       Aircraft: Number of engines?      Aircraft: Airline/Operator  ...  \
# 4013                           NaN  BOEING COMMERCIAL AIRPLANE GRP  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 4013              Approach                      None         Medium
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 4013        No Cloud   California gull                                  N
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# 4013             0              100.0                         0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'HU-25']
# Out:
#                           Airport: Name Altitude bin Aircraft: Make/Model  \
# 4208   CAPE COD COAST GUARD AIR STATION    < 1000 ft                HU-25
# 19064        HOMESTEAD AIR RESERVE BASE    < 1000 ft                HU-25
# 22468        HOMESTEAD AIR RESERVE BASE    < 1000 ft                HU-25
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 4208                  2 to 10                               6
# 19064                       1                               1
# 22468                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 4208     Precautionary Landing  2011-10-05                No damage
# 19064                    Other  2009-07-27                No damage
# 22468                     None  2010-09-30                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 4208                            NaN                 GOVERNMENT  ...
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'HOMEBUILT']
# Out:
#                         Airport: Name Altitude bin Aircraft: Make/Model  \
# 4402         TEHACHAPI MUNICIPAL ARPT    > 1000 ft            HOMEBUILT
# 15940  KENDALL-TAMIAMI EXECUTIVE ARPT    > 1000 ft            HOMEBUILT
# 16487              METRO OAKLAND INTL    < 1000 ft            HOMEBUILT
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 4402                11 to 100                              93
# 15940                       1                               1
# 16487                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 4402                      None  2003-01-27            Caused damage
# 15940    Precautionary Landing  2008-01-26            Caused damage
# 16487                     None  2008-06-14                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 4402                            NaN            PRIVATELY OWNED  ...
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'F-15E']
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 4667  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft                F-15E
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 4667                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 4667    Precautionary Landing  2000-01-25            Caused damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 4667                           NaN                   MILITARY  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 4667                 Climb                      None          Large
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 4667        No Cloud    Turkey vulture                                  Y
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'KC-135R']
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 4960       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft              KC-135R
# 5821       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft              KC-135R
# 7830            CHARLESTON AFB/INTL ARPT    < 1000 ft              KC-135R
# 7892  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft              KC-135R
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 4960                       1                               1
# 5821                       1                               1
# 7830                       1                               1
# 7892                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 4960    Precautionary Landing  2000-05-24                No damage
# 5821    Precautionary Landing  2001-02-23                No damage
# 7830                     None  2002-10-07                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'GRUMMAN']
# Out:
#         Airport: Name Altitude bin Aircraft: Make/Model  \
# 5196  HEMET-RYAN ARPT    < 1000 ft              GRUMMAN
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 5196                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 5196                     None  2000-07-31            Caused damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 5196                           NaN                 GOVERNMENT  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 5196          Take-off run                      None         Medium
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 5196        No Cloud   Red-tailed hawk                                  N
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# 5196          8018                0.0                         0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == "MC-130H"]
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 5733  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft              MC-130H
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 5733                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 5733                     None  2000-11-27                No damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 5733                           NaN                   MILITARY  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 5733              Approach                      None         Medium
#
#      Conditions: Sky    Wildlife: Species Pilot warned of birds or wildlife?  \
# 5733        No Cloud  Unknown bird or bat                                  Y
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'KC-135R']
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 4960       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft              KC-135R
# 5821       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft              KC-135R
# 7830            CHARLESTON AFB/INTL ARPT    < 1000 ft              KC-135R
# 7892  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft              KC-135R
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 4960                       1                               1
# 5821                       1                               1
# 7830                       1                               1
# 7892                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 4960    Precautionary Landing  2000-05-24                No damage
# 5821    Precautionary Landing  2001-02-23                No damage
# 7830                     None  2002-10-07                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'F-16C']
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 7250  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft                F-16C
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 7250                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 7250                     None  2002-06-24                No damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 7250                           NaN                   MILITARY  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 7250              Approach                      None         Medium
#
#      Conditions: Sky    Wildlife: Species Pilot warned of birds or wildlife?  \
# 7250      Some Cloud  Unknown bird or bat                                  Y
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'T-1A']
# Out:
#                       Airport: Name Altitude bin Aircraft: Make/Model  \
# 7368  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                 T-1A
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 7368                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 7368                     None  2002-07-20                No damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 7368                           NaN                   MILITARY  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 7368              Approach                      None          Small
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 7368        No Cloud      Barn swallow                                  Y
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'F-15C']
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 7525  EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft                F-15C
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 7525                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 7525                     None  2002-08-13                No damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 7525                           NaN                   MILITARY  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 7525          Take-off run                      None          Small
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 7525        No Cloud     Cliff swallow                                  Y
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'E-8C']
# Out:
#                       Airport: Name Altitude bin Aircraft: Make/Model  \
# 7644  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                 E-8C
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 7644                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 7644    Precautionary Landing  2002-09-04                No damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 7644                           NaN                   MILITARY  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 7644                 Climb                      None          Small
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 7644        No Cloud  Common nighthawk                                  Y
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CANADAIR']
# Out:
#                     Airport: Name Altitude bin Aircraft: Make/Model  \
# 8497  DALLAS/FORT WORTH INTL ARPT    < 1000 ft             CANADAIR
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 8497                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 8497         Aborted Take-off  2003-06-21                No damage
#
#       Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 8497                           NaN         ATLANTIC SOUTHEAST  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 8497          Take-off run                      None          Small
#
#      Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 8497      Some Cloud     Mourning dove                                  N
#
#      Cost: Total $  Feet above ground  Number of people injured  \
# 8497             0                0.0                         0
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CL-215']
# Out:
#        Airport: Name Altitude bin Aircraft: Make/Model  \
# 11853  VAN NUYS ARPT    < 1000 ft               CL-215
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 11853                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 11853                     None  2005-10-01                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 11853                           NaN                 GOVERNMENT  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 11853          Landing Roll                      None         Medium
#
#       Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 11853        Overcast     American coot                                  N
#
#       Cost: Total $  Feet above ground  Number of people injured  \
# 11853             0                0.0                         0
#
# ...

# %%
# Sample DataFrame


# Define specific rows and column
rows_to_fill = [3540,3666, 13814,14726,14918,15631,16001,16457, 21427,21520]
column_to_fill = 'Aircraft: Number of engines?'

# Isolate the subset
subset = bird_strike2.loc[rows_to_fill, column_to_fill]

# %%
filled_subset = subset.bfill()

# %%
filled_subset 
bird_strike2.loc[rows_to_fill, column_to_fill] = filled_subset

# %%
bird_strike2.isnull().sum()
# Out:
# Airport: Name                           0
# Altitude bin                            0
# Aircraft: Make/Model                    0
# Wildlife: Number struck                 0
# Wildlife: Number Struck Actual          0
# Effect: Impact to flight                0
# FlightDate                              0
# Effect: Indicated Damage                0
# Aircraft: Number of engines?          227
# Aircraft: Airline/Operator              0
# Origin State                          449
# When: Phase of flight                   0
# Conditions: Precipitation               0
# Wildlife: Size                          0
# Conditions: Sky                         0
# Wildlife: Species                       0
# Pilot warned of birds or wildlife?      0
# Cost: Total $                           0
# Feet above ground                       0
# Number of people injured                0
# Is Aircraft Large?                      0
# dtype: int64

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'AMD ALARUS CH2000']
# Out:
#                 Airport: Name Altitude bin Aircraft: Make/Model  \
# 12932  LONG ISLAND MAC ARTHUR    < 1000 ft    AMD ALARUS CH2000
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 12932                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 12932                     None  2006-07-13                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 12932                           NaN                   BUSINESS  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 12932          Landing Roll                      None          Small
#
#       Conditions: Sky     Wildlife: Species  \
# 12932        Overcast  Unknown bird - small
#
#       Pilot warned of birds or wildlife? Cost: Total $  Feet above ground  \
# 12932                                  N             0                0.0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'ECLIPSE 500']
# Out:
#                        Airport: Name Altitude bin Aircraft: Make/Model  \
# 17504           GROTON-NEW LONDON AR    < 1000 ft          ECLIPSE 500
# 17693           LOUISVILLE INTL ARPT    < 1000 ft          ECLIPSE 500
# 18482         CHICAGO EXECUTIVE ARPT    > 1000 ft          ECLIPSE 500
# 19375  BIRMINGHAM-SHUTTLESWORTH INTL    < 1000 ft          ECLIPSE 500
# 22659           UNIVERSITY PARK ARPT    < 1000 ft          ECLIPSE 500
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 17504                       1                               1
# 17693                       1                               1
# 18482                       1                               1
# 19375                       1                               1
# 22659                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 17504                     None  2008-10-26                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CESSNA LC-41']
# Out:
#            Airport: Name Altitude bin Aircraft: Make/Model  \
# 17940  TETERBORO AIRPORT    < 1000 ft         CESSNA LC-41
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 17940                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 17940         Aborted Take-off  2009-03-07                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 17940                           NaN                   BUSINESS  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 17940          Take-off run                      None          Large
#
#       Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 17940        No Cloud      Canada goose                                  Y
#
#       Cost: Total $  Feet above ground  Number of people injured  \
# 17940             0                0.0                         0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'SA227 DC METRO 23']
# Out:
#             Airport: Name Altitude bin Aircraft: Make/Model  \
# 17960  SANTA MARIA PUBLIC    < 1000 ft    SA227 DC METRO 23
# 18747   ONTARIO INTL ARPT    < 1000 ft    SA227 DC METRO 23
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 17960                       1                               1
# 18747                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 17960                     None  2009-03-13                No damage
# 18747                     None  2009-06-30                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 17960                           NaN                AMERIFLIGHT  ...
# 18747                           NaN                AMERIFLIGHT  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 17960              Approach                      None          Small
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'GRUMMAN S-2 TRACKER']
# Out:
#                 Airport: Name Altitude bin Aircraft: Make/Model  \
# 19048  NEVADA COUNTY AIR PARK    < 1000 ft  GRUMMAN S-2 TRACKER
# 24125    UKIAH MUNICIPAL ARPT    < 1000 ft  GRUMMAN S-2 TRACKER
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 19048                       1                               1
# 24125                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 19048                     None  2009-07-25            Caused damage
# 24125                     None  2011-07-22                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 19048                           NaN                   BUSINESS  ...
# 24125                           NaN                 GOVERNMENT  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 19048              Approach                      None          Small
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'HC-130']
# Out:
#              Airport: Name Altitude bin Aircraft: Make/Model  \
# 20706  MC CLELLAN AIRFIELD    < 1000 ft               HC-130
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 20706                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 20706                     None  2010-03-17            Caused damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 20706                           NaN                 GOVERNMENT  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 20706              Approach                      None          Small
#
#       Conditions: Sky     Wildlife: Species  \
# 20706        No Cloud  Unknown bird - small
#
#       Pilot warned of birds or wildlife? Cost: Total $  Feet above ground  \
# 20706                                  N             0               10.0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'T-38N']
# Out:
#               Airport: Name Altitude bin Aircraft: Make/Model  \
# 20876  ELLINGTON FIELD ARPT    > 1000 ft                T-38N
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 20876                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 20876                     None  2010-04-22                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 20876                           NaN                 GOVERNMENT  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 20876              Approach                      None          Small
#
#       Conditions: Sky     Wildlife: Species  \
# 20876      Some Cloud  Unknown bird - small
#
#       Pilot warned of birds or wildlife? Cost: Total $  Feet above ground  \
# 20876                                  N             0             1600.0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'T-38']
# Out:
#               Airport: Name Altitude bin Aircraft: Make/Model  \
# 22280  ELLINGTON FIELD ARPT    < 1000 ft                 T-38
# 22781  ELLINGTON FIELD ARPT    < 1000 ft                 T-38
# 23971  ELLINGTON FIELD ARPT    < 1000 ft                 T-38
# 24725  ELLINGTON FIELD ARPT    < 1000 ft                 T-38
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 22280                       1                               1
# 22781                       1                               1
# 23971                       1                               1
# 24725                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 22280                     None  2010-09-14                No damage
# 22781                     None  2010-11-01                No damage
# 23971                     None  2011-07-06                No damage
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'B-737-600']
# Out:
#           Airport: Name Altitude bin Aircraft: Make/Model  \
# 22387     MCCARREN INTL    < 1000 ft            B-737-600
# 23774  LOS ANGELES INTL    < 1000 ft            B-737-600
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 22387                       1                               1
# 23774                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 22387                     None  2010-09-23                No damage
# 23774                     None  2011-06-10                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 22387                           NaN                   BUSINESS  ...
# 23774                           NaN                    WESTJET  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 22387                 Climb                      None          Small
# ...

# %%
rows_to_fill2 = [3574, 23032]
column_to_fill2 = 'Aircraft: Number of engines?'

subset2 = bird_strike2.loc[rows_to_fill2, column_to_fill2]

filled_subset2 = subset2.ffill()

bird_strike2.loc[rows_to_fill2, column_to_fill2] = filled_subset2

# %%
bird_strike2.isnull().sum()
# Out:
# Airport: Name                           0
# Altitude bin                            0
# Aircraft: Make/Model                    0
# Wildlife: Number struck                 0
# Wildlife: Number Struck Actual          0
# Effect: Impact to flight                0
# FlightDate                              0
# Effect: Indicated Damage                0
# Aircraft: Number of engines?          226
# Aircraft: Airline/Operator              0
# Origin State                          449
# When: Phase of flight                   0
# Conditions: Precipitation               0
# Wildlife: Size                          0
# Conditions: Sky                         0
# Wildlife: Species                       0
# Pilot warned of birds or wildlife?      0
# Cost: Total $                           0
# Feet above ground                       0
# Number of people injured                0
# Is Aircraft Large?                      0
# dtype: int64

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'A-23 MUSKATEER']
# Out:
#                   Airport: Name Altitude bin Aircraft: Make/Model  \
# 23189  STILLWATER REGIONAL ARPT    < 1000 ft       A-23 MUSKATEER
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 23189                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 23189                    Other  2011-03-10            Caused damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 23189                           NaN            PRIVATELY OWNED  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 23189          Landing Roll                      None          Large
#
#       Conditions: Sky  Wildlife: Species Pilot warned of birds or wildlife?  \
# 23189        No Cloud  White-tailed deer                                  N
#
#       Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'LOCKHEED P3A']
# Out:
#                    Airport: Name Altitude bin Aircraft: Make/Model  \
# 23237  DANIEL ODUBER QUIROS INTL    < 1000 ft         LOCKHEED P3A
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 23237                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 23237                     None  2011-03-21                No damage
#
#        Aircraft: Number of engines?        Aircraft: Airline/Operator  ...  \
# 23237                           NaN  US CUSTOMS AND BORDER PROTECTION  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 23237              Approach                      None          Small
#
#       Conditions: Sky     Wildlife: Species  \
# 23237      Some Cloud  Unknown bird - small
#
#       Pilot warned of birds or wildlife? Cost: Total $  Feet above ground  \
# 23237                                  N             0              500.0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CRJ-900']
# Out:
#                  Airport: Name Altitude bin Aircraft: Make/Model  \
# 23241  SANTA BARBARA MUNICIPAL    < 1000 ft              CRJ-900
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 23241                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 23241                     None  2011-03-22                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 23241                           NaN              MESA AIRLINES  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 23241              Approach                      None         Medium
#
#       Conditions: Sky Wildlife: Species Pilot warned of birds or wildlife?  \
# 23241        No Cloud      Western gull                                  Y
#
#       Cost: Total $  Feet above ground  Number of people injured  \
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'FLIGHT DESIGN CTSW']
# Out:
#                      Airport: Name Altitude bin Aircraft: Make/Model  \
# 23649  LORAIN COUNTY REGIONAL ARPT    > 1000 ft   FLIGHT DESIGN CTSW
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 23649                       1                               1
#
#       Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 23649    Precautionary Landing  2011-05-22                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 23649                           NaN                   BUSINESS  ...
#
#       When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 23649              Approach                      None          Small
#
#       Conditions: Sky     Wildlife: Species  \
# 23649        No Cloud  Unknown bird - small
#
#       Pilot warned of birds or wildlife? Cost: Total $  Feet above ground  \
# 23649                                  N             0             2400.0
#
# ...

# %%
bird_strike2[bird_strike2['Aircraft: Make/Model'] == 'CL-RJ705']
# Out:
#       Airport: Name Altitude bin Aircraft: Make/Model Wildlife: Number struck  \
# 23714    LOGAN INTL    < 1000 ft             CL-RJ705                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  FlightDate  \
# 23714                               1                     None  2011-05-31
#
#       Effect: Indicated Damage  Aircraft: Number of engines?  \
# 23714                No damage                           NaN
#
#       Aircraft: Airline/Operator  ... When: Phase of flight  \
# 23714            AIR CANADA JAZZ  ...                 Climb
#
#       Conditions: Precipitation Wildlife: Size Conditions: Sky  \
# 23714                      None          Small        No Cloud
#
#       Wildlife: Species Pilot warned of birds or wildlife? Cost: Total $  \
# 23714          Killdeer                                  Y             0
#
#        Feet above ground  Number of people injured  Is Aircraft Large?
# ...

# %%
bird_strike2.isnull().sum()
# Out:
# Airport: Name                           0
# Altitude bin                            0
# Aircraft: Make/Model                    0
# Wildlife: Number struck                 0
# Wildlife: Number Struck Actual          0
# Effect: Impact to flight                0
# FlightDate                              0
# Effect: Indicated Damage                0
# Aircraft: Number of engines?          226
# Aircraft: Airline/Operator              0
# Origin State                          449
# When: Phase of flight                   0
# Conditions: Precipitation               0
# Wildlife: Size                          0
# Conditions: Sky                         0
# Wildlife: Species                       0
# Pilot warned of birds or wildlife?      0
# Cost: Total $                           0
# Feet above ground                       0
# Number of people injured                0
# Is Aircraft Large?                      0
# dtype: int64

# %%
bird_strike2.to_csv(r"D:\UM internship\Bird Strike\Bird_strike2.csv")

# %%
bird_strike2['Aircraft: Number of engines?'].unique()
# Out:
# array([ 2.,  3.,  4., nan,  1.])

# %%
bird_strike2.iloc[3574:,:]
# Out:
#        Unnamed: 0                    Airport: Name Altitude bin  \
# 3574         3576       COLORADO SPRINGS MUNICIPAL    < 1000 ft
# 3575         3577                LOVELL FIELD ARPT    < 1000 ft
# 3576         3578               JACKSON EVERS INTL    < 1000 ft
# 3577         3579          SAN FRANCISCO INTL ARPT    < 1000 ft
# 3578         3580               PORT COLUMBUS INTL    > 1000 ft
# ...           ...                              ...          ...
# 25424       25552                  SACRAMENTO INTL    < 1000 ft
# 25425       25553                REDDING MUNICIPAL    > 1000 ft
# 25426       25554                     ORLANDO INTL    < 1000 ft
# 25427       25556  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25428       25557     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 3574        B-747-8 SERIES                 2 to 10
# 3575               EMB-145                 2 to 10
# ...
