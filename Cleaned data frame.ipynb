# %%
import pandas as pd
import numpy as np

# %%
URL = r"D:\UM internship\Bird Strike\birdstrike_filterspecies_new.csv"
df = pd.read_csv(URL)
df.head()
# Out:
#    Unnamed: 0                      Airport: Name Altitude bin  \
# 0           0                   KANSAS CITY INTL    < 1000 ft
# 1           1  CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft
# 2           2                         MIAMI INTL    > 1000 ft
# 3           3        SOUTHWEST FLORIDA INTL ARPT    < 1000 ft
# 4           4                     NASHVILLE INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0                MD-80               11 to 100
# 1          CITATION II                       1
# 2              DA-2000                       1
# 3           HAWKER 800                       1
# 4            B-737-400                       1
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                              54                     None   1/2/2000
# 1                               1                     None   1/2/2000
# 2                               1                     None   1/2/2000
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df1 = df.copy()

# %%
df1
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                       KANSAS CITY INTL    < 1000 ft                MD-80
# 1      CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft          CITATION II
# 2                             MIAMI INTL    > 1000 ft              DA-2000
# 3            SOUTHWEST FLORIDA INTL ARPT    < 1000 ft           HAWKER 800
# 4                         NASHVILLE INTL    < 1000 ft            B-737-400
# ...                                  ...          ...                  ...
# 25198                       ORLANDO INTL    < 1000 ft                A-321
# 25199                  REDDING MUNICIPAL    > 1000 ft              EMB-120
# 25200    DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft            B-757-200
# 25201       GEORGE BUSH INTERCONTINENTAL    < 1000 ft              EMB-145
# 25202       ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft            B-737-400
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
df1.isnull().sum()
# Out:
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                 93
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4752
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# ...

# %%
df1.dropna(subset= ['Aircraft: Number of engines?', 'Origin State'], inplace = True)

# %%
df1.isnull().sum()
# Out:
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                  0
# Aircraft: Airline/Operator                    0
# Origin State                                  0
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4620
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# ...

# %%
df1.drop(['Remarks'], axis = 1, inplace = True)

# %%
df1.isnull().sum()
# Out:
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# Pilot warned of birds or wildlife?         0
# Cost: Total $                              0
# Feet above ground                          0
# ...

# %%
df1.to_csv(r'D:\UM internship\Bird Strike\cleaned_data_with_filterspecies.csv', index = False)
