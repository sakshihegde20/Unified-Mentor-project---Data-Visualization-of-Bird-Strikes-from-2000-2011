# %%
import pandas as pd
import numpy as np

# %%
URL = r"D:\UM internship\Bird Strike\Bird Strikes data.xlsx"

bird_df = pd.read_excel(URL)

# %%
bird_df.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
# ...

# %%
bird_df.shape
# Out:
# (25558, 26)

# %%
bird_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 25429 non-null  object
#  8   FlightDate                               25429 non-null  datetime64[ns]
#  9   Effect: Indicated Damage                 25558 non-null  object
# ...

# %%
bird_df.isnull().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                              129
# Airport: Name                               129
# Altitude bin                                129
# Aircraft: Make/Model                          0
# Wildlife: Number struck                     129
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                    129
# FlightDate                                  129
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                267
# Aircraft: Airline/Operator                  129
# Origin State                                449
# When: Phase of flight                       129
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4771
# Wildlife: Size                              129
# Conditions: Sky                               0
# ...

# %%
bird_df.iloc[5,0:].to_frame()
# Out:
#                                                                                5
# Record ID                                                                 218432
# Aircraft: Type                                                          Airplane
# Airport: Name                                                GUAYAQUIL/S BOLIVAR
# Altitude bin                                                           < 1000 ft
# Aircraft: Make/Model                                                       A-300
# Wildlife: Number struck                                                 Over 100
# Wildlife: Number Struck Actual                                               537
# Effect: Impact to flight                                                    None
# FlightDate                                                   2003-07-24 00:00:00
# Effect: Indicated Damage                                               No damage
# Aircraft: Number of engines?                                                   2
# ...

# %%
bird_df.drop('Record ID', axis = 1, inplace = True)

# %%
bird_df.head(3)
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       Airplane            LAKEFRONT AIRPORT    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
# 2                             261                     None 2001-09-14
#
#   Effect: Indicated Damage Aircraft: Number of engines?  ...  \
# 0            Caused damage                            2  ...
# 1            Caused damage                            2  ...
# 2                No damage                            2  ...
#
# ...

# %%
bird_df['Aircraft: Type'].unique()
# Out:
# array(['Airplane', nan], dtype=object)

# %%
bird_df['Airport: Name'].nunique()
# Out:
# 1109

# %%
bird_df['Airport: Name'].duplicated().sum()
# Out:
# 24448

# %%
values_counts = bird_df['Airport: Name'].value_counts()
duplicated_value_counts = values_counts[values_counts > 1]

# %%
duplicated_value_counts
# Out:
# DALLAS/FORT WORTH INTL ARPT    803
# SACRAMENTO INTL                676
# SALT LAKE CITY INTL            479
# DENVER INTL AIRPORT            476
# KANSAS CITY INTL               452
#                               ...
# ARNOLD PALMER REGIONAL           2
# ROBT L BRADSHAW INTL             2
# RAFAEL HERNANDEZ ARPT            2
# DELTA COUNTY ARPT                2
# PETER O KNIGHT ARPT              2
# Name: Airport: Name, Length: 707, dtype: int64

# %%
bird_df.drop(['Remains of wildlife collected?',
              'Remains of wildlife sent to Smithsonian','Remarks'], axis = 1, inplace = True)

# %%
bird_df.drop('Aircraft: Type', axis = 1, inplace = True)

# %%
bird_df.head()
# Out:
#                  Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                 LAGUARDIA NY    > 1000 ft            B-737-400
# 1  DALLAS/FORT WORTH INTL ARPT    < 1000 ft                MD-80
# 2            LAKEFRONT AIRPORT    < 1000 ft                C-500
# 3          SEATTLE-TACOMA INTL    < 1000 ft            B-737-400
# 4                 NORFOLK INTL    < 1000 ft         CL-RJ100/200
#
#   Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 0                Over 100                             859
# 1                Over 100                             424
# 2                Over 100                             261
# 3                Over 100                             806
# 4                Over 100                             942
#
#   Effect: Impact to flight FlightDate Effect: Indicated Damage  \
# 0         Engine Shut Down 2000-11-23            Caused damage
# 1                     None 2001-07-25            Caused damage
# ...

# %%
bird_df.shape
# Out:
# (25558, 24)

# %%
bird_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Airport: Name                            25429 non-null  object
#  1   Altitude bin                             25429 non-null  object
#  2   Aircraft: Make/Model                     25558 non-null  object
#  3   Wildlife: Number struck                  25429 non-null  object
#  4   Wildlife: Number Struck Actual           25558 non-null  int64
#  5   Effect: Impact to flight                 25429 non-null  object
#  6   FlightDate                               25429 non-null  datetime64[ns]
#  7   Effect: Indicated Damage                 25558 non-null  object
#  8   Aircraft: Number of engines?             25291 non-null  object
#  9   Aircraft: Airline/Operator               25429 non-null  object
# ...

# %%
bird_df.isnull().sum()
# Out:
# Airport: Name                               129
# Altitude bin                                129
# Aircraft: Make/Model                          0
# Wildlife: Number struck                     129
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                    129
# FlightDate                                  129
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                267
# Aircraft: Airline/Operator                  129
# Origin State                                449
# When: Phase of flight                       129
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4771
# Wildlife: Size                              129
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?          129
# ...

# %%
bird_df.dropna(subset=['Airport: Name'], axis = 0, inplace = True)

# %%
bird_df.isnull().sum()
# Out:
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                234
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4761
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# ...

# %%
bird_df.to_csv(r"D:\UM internship\Bird Strike\birdnew.csv")

# %%
bird_df['Aircraft: Number of engines?'].unique()
# Out:
# array([2, 3, 4, nan, 1], dtype=object)

# %%
value_counts = bird_df['Aircraft: Number of engines?'].value_counts()
number_of_missing_values = value_counts[value_counts == 0]

# %%
bird_df['Aircraft: Number of engines?'].unique()
# Out:
# array([2, 3, 4, nan, 1, 'C'], dtype=object)

# %%
B = bird_df[bird_df['Aircraft: Number of engines?'] == 'C']

# %%
B
# Out:
#                   Airport: Name Altitude bin Aircraft: Make/Model  \
# 6664  MORGANTOWN MUNICIPAL ARPT    > 1000 ft         RKWLTRBO 690
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 6664                       1                               1
#
#      Effect: Impact to flight FlightDate Effect: Indicated Damage  \
# 6664                     None 2001-11-05                No damage
#
#      Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 6664                            C                   BUSINESS  ...
#
#      When: Phase of flight Conditions: Precipitation Wildlife: Size  \
# 6664               Descent                      None         Medium
#
#      Conditions: Sky      Wildlife: Species  \
# 6664        No Cloud  Unknown bird - medium
#
#      Pilot warned of birds or wildlife? Cost: Total $  Feet above ground  \
# 6664                                  N             0             4000.0
#
# ...

# %%
bird_df.at[6664,'Aircraft: Number of engines?'] = 2

# %%
filtered_df = bird_df[bird_df['Aircraft: Make/Model'] == 'RKWLTRBO 690']
filtered_df
# Out:
#                           Airport: Name Altitude bin Aircraft: Make/Model  \
# 208       BIRMINGHAM-SHUTTLESWORTH INTL    < 1000 ft         RKWLTRBO 690
# 2519               NORTH BEND MUNICIPAL    < 1000 ft         RKWLTRBO 690
# 3760                            ADDISON    < 1000 ft         RKWLTRBO 690
# 3775            PORTLAND-HILLSBORO ARPT    < 1000 ft         RKWLTRBO 690
# 4447                 BARROW COUNTY ARPT    < 1000 ft         RKWLTRBO 690
# 5030            LAFAYETTE REGIONAL (LA)    > 1000 ft         RKWLTRBO 690
# 6640          FORT SMITH MUNICIPAL ARPT    < 1000 ft         RKWLTRBO 690
# 6664          MORGANTOWN MUNICIPAL ARPT    > 1000 ft         RKWLTRBO 690
# 7269                       BOWMAN FIELD    < 1000 ft         RKWLTRBO 690
# 9279               BOEING FIELD K C INT    < 1000 ft         RKWLTRBO 690
# 10128                     VAN NUYS ARPT    < 1000 ft         RKWLTRBO 690
# 11972                 ROGUE VALLEY INTL    > 1000 ft         RKWLTRBO 690
# ...

# %%
bird_df[pd.isnull(bird_df['Aircraft: Number of engines?'])]
# Out:
#                           Airport: Name Altitude bin Aircraft: Make/Model  \
# 42        BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 61        BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# 211       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 217            CHARLESTON AFB/INTL ARPT    > 1000 ft                C-17A
# 221       BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# ...                                 ...          ...                  ...
# 25076              ELLINGTON FIELD ARPT    < 1000 ft                T-38A
# 25159               JOHN F KENNEDY INTL    < 1000 ft              CRJ-440
# 25184    FORT LAUDERDALE EXECUTIVE ARPT    < 1000 ft            PA-31-350
# 25215                HONOLULU INTL ARPT    < 1000 ft               F/A-18
# 25474  KALAELOA ARPT JOHN RODGERS FIELD    < 1000 ft                DA-40
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
filtered_data = bird_df[bird_df['Aircraft: Make/Model'] == 'B-52H']
filtered_data
# Out:
#                       Airport: Name Altitude bin Aircraft: Make/Model  \
# 42    BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 61    BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# 211   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 221   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 286   BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# 340   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 483   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 533   BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# 552   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 583   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 658   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 746   BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# ...

# %%
result = filtered_data['Aircraft: Number of engines?']
# Out:
# 42      NaN
# 61      NaN
# 211     NaN
# 221     NaN
# 286     NaN
# 340     NaN
# 483     NaN
# 533     NaN
# 552     NaN
# 583     NaN
# 658     NaN
# 746     NaN
# 4835    NaN
# 4936    NaN
# 5743    NaN
# 5891    NaN
# 5910    NaN
# 5936    NaN
# 5958    NaN
# 5959    NaN
# 6012    NaN
# 6106    NaN
# 6351    NaN
# 6638    NaN
# 7050    NaN
# 7355    NaN
# 7370    NaN
# 8005    NaN
# Name: Aircraft: Number of engines?, dtype: object

# %%
bird_df.to_csv(r'D:\UM internship\Bird Strike\bird_strike_URMproject.csv')
