# %%
import pandas as pd
import numpy as np

# %%
URL = r"D:\UM internship\Bird Strike\birdstrike_filterspecies.csv"
birdspecies_filter = pd.read_csv(URL)
birdspecies_filter.head()
# Out:
#    Unnamed: 0                      Airport: Name Altitude bin  \
# 0           0                   KANSAS CITY INTL    < 1000 ft
# 1           1  CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft
# 2           2                         MIAMI INTL    > 1000 ft
# 3           3        SOUTHWEST FLORIDA INTL ARPT    < 1000 ft
# 4           4                     NASHVILLE INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0                MD-80               11 to 100
# 1          CITATION II                       1
# 2              DA-2000                       1
# 3           HAWKER 800                       1
# 4            B-737-400                       1
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                              54                     None   1/2/2000
# 1                               1                     None   1/2/2000
# 2                               1                     None   1/2/2000
# ...

# %%
birdspecies_filter.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
birdspecies_filter.head()
# Out:
#                        Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                   KANSAS CITY INTL    < 1000 ft                MD-80
# 1  CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft          CITATION II
# 2                         MIAMI INTL    > 1000 ft              DA-2000
# 3        SOUTHWEST FLORIDA INTL ARPT    < 1000 ft           HAWKER 800
# 4                     NASHVILLE INTL    < 1000 ft            B-737-400
#
#   Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 0               11 to 100                              54
# 1                       1                               1
# 2                       1                               1
# 3                       1                               1
# 4                       1                               1
#
#   Effect: Impact to flight FlightDate Effect: Indicated Damage  \
# 0                     None   1/2/2000                No damage
# ...

# %%
birdspecies_filter['Altitude bin'].unique
# Out:
# <bound method Series.unique of 0        < 1000 ft
# 1        < 1000 ft
# 2        > 1000 ft
# 3        < 1000 ft
# 4        < 1000 ft
#            ...
# 25198    < 1000 ft
# 25199    > 1000 ft
# 25200    < 1000 ft
# 25201    < 1000 ft
# 25202    < 1000 ft
# Name: Altitude bin, Length: 25203, dtype: object>

# %%
birdspecies_filter.shape
# Out:
# (25203, 24)

# %%
birdspecies_filter.describe()
# Out:
#        Wildlife: Number Struck Actual  Aircraft: Number of engines?  \
# count                    25203.000000                  24978.000000
# mean                         2.713526                      2.005765
# std                         12.882044                      0.363550
# min                          1.000000                      1.000000
# 25%                          1.000000                      2.000000
# 50%                          1.000000                      2.000000
# 75%                          1.000000                      2.000000
# max                        942.000000                      4.000000
#
#        Cost: Total $  Feet above ground  Number of people injured
# count   2.520300e+04       25203.000000              25203.000000
# mean    4.846457e+03         805.499345                  0.000754
# std     9.385988e+04        1745.988738                  0.045852
# min     0.000000e+00           0.000000                  0.000000
# ...

# %%
birdspecies_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25203 entries, 0 to 25202
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Airport: Name                            25203 non-null  object
#  1   Altitude bin                             25203 non-null  object
#  2   Aircraft: Make/Model                     25203 non-null  object
#  3   Wildlife: Number struck                  25203 non-null  object
#  4   Wildlife: Number Struck Actual           25203 non-null  int64
#  5   Effect: Impact to flight                 25203 non-null  object
#  6   FlightDate                               25203 non-null  object
#  7   Effect: Indicated Damage                 25203 non-null  object
#  8   Aircraft: Number of engines?             24978 non-null  float64
#  9   Aircraft: Airline/Operator               25203 non-null  object
# ...

# %%
birdspecies_filter['Origin State'].isnull().sum()
# Out:
# 449

# %%
birdspecies_filter['Origin State'].value_counts()
# Out:
# California                   2478
# Texas                        2431
# Florida                      2027
# New York                     1304
# Illinois                      999
# Pennsylvania                  969
# Missouri                      950
# Kentucky                      806
# Ohio                          761
# Hawaii                        716
# Michigan                      663
# Colorado                      660
# Tennessee                     651
# North Carolina                649
# New Jersey                    589
# Georgia                       504
# Utah                          489
# DC                            432
# Maryland                      427
# Oregon                        388
# Louisiana                     380
# Nebraska                      367
# Arizona                       349
# Massachusetts                 348
# Minnesota                     347
# Indiana                       339
# Washington                    327
# ...

# %%
birdspecies_filter.isnull().sum()
# Out:
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                225
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4752
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# ...

# %%
birdspecies_filter['Conditions: Sky'].unique()
# Out:
# array(['No Cloud', 'Overcast', 'Some Cloud'], dtype=object)

# %%
percentage_missing = (225 / len(birdspecies_filter)) * 100
percentage_missing
# Out:
# 0.8927508629925008

# %%
birdspecies_filter['Conditions: Precipitation'].value_counts()
# Out:
# None               23209
# Rain                1341
# Fog                  469
# Snow                  86
# Fog, Rain             85
# Rain, Snow             6
# Fog, Snow              4
# Fog, Rain, Snow        3
# Name: Conditions: Precipitation, dtype: int64

# %%
birdspecies_filter['Aircraft: Number of engines?'].unique()
# Out:
# array([ 2.,  3.,  1., nan,  4.])

# %%
total_strike_count = birdspecies_filter.shape[0]
total_strike_count
# Out:
# 25203

# %%
birdspecies_filter['Aircraft: Number of engines?']
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 25198    2.0
# 25199    2.0
# 25200    2.0
# 25201    2.0
# 25202    2.0
# Name: Aircraft: Number of engines?, Length: 25203, dtype: float64

# %%
filtered_df = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'] == 2]



# Assuming your DataFrame is named birdspecies_filter

# Step 1: Filter the dataset for rows where 'Damage Location' contains the substring 'engine'
filtered_df2 = filtered_df[filtered_df['Remarks'].str.contains('eng', case=False, na=False)]

# Step 2: Optionally, select specific columns of interest
# result = filtered_df[['Column1', 'Column2']]  # replace 'Column1' and 'Column2' with actual column names

# Display the filtered result
filtered_df2[['Aircraft: Number of engines?', 'Remarks']]
# Out:
#        Aircraft: Number of engines?  \
# 3                               2.0
# 5                               2.0
# 6                               2.0
# 14                              2.0
# 29                              2.0
# ...                             ...
# 25188                           2.0
# 25189                           2.0
# 25190                           2.0
# 25191                           2.0
# 25196                           2.0
#
#                                                  Remarks
# 3      SUSPECT GULL. HEARD THUMP ON APCH BUT NO ABNRM...
# 5      PREC. LDG. ENG SHUT DOWN. INGESTION. ENG VIBRA...
# 6      FLT 128 ENCOUNTERED 15-20 BIRDS.  AT 1000 FT, ...
# 14     FLEW THRU A FLOCK OF ABOUT 30 BIRDS. INGESTED ...
# 29     JUST OUTSIDE OF WILLT ON VISUAL APCH, WE FLEW ...
# ...                                                  ...
# 25188  ID BY SMITHSONIAN. MULTIPLE SPECIES. SAMPLE 1 ...
# 25189  ID BY SMITHSONIAN. BIRD HIT FUSELAGE THEN WENT...
# ...

# %%
filtered_df2[['Aircraft: Number of engines?', 'Remarks']]
# Out:
#        Aircraft: Number of engines?  \
# 1341                            2.0
# 1463                            2.0
# 2095                            2.0
# 3351                            2.0
# 3436                            2.0
# ...                             ...
# 24377                           2.0
# 24446                           2.0
# 24819                           2.0
# 25102                           2.0
# 25189                           2.0
#
#                                                  Remarks
# 1341   ENGINE WAS CHANGED AND DENTED COWLING WAS REPL...
# 1463   RETD TO ARPT AFTER REPORTING A BIRDSTRIKE SHOR...
# 2095   FLT 657 RETD TO LAND AFTER A BIRD STRIKE. BOTH...
# 3351   FLEW THRU A FLOCK. NO STRIKES NOTED. POST FLT ...
# 3436   CREW NOTICED AN UNUSUAL VIBRATION IN ONE ENG. ...
# ...                                                  ...
# 24377  ID BY SMITHSONIAN. PORT AUTH RECVD A CALL FROM...
# 24446  NUMEROUS STRIKES ON NOSE AND INSIDE BOTH ENGIN...
# ...

# %%
filtered_df_engine2[['Aircraft: Number of engines?', 'Remarks']]
# Out:
#        Aircraft: Number of engines?  \
# 1341                            2.0
# 1463                            2.0
# 2095                            2.0
# 3351                            2.0
# 3436                            2.0
# ...                             ...
# 24377                           2.0
# 24446                           2.0
# 24819                           2.0
# 25102                           2.0
# 25189                           2.0
#
#                                                  Remarks
# 1341   ENGINE WAS CHANGED AND DENTED COWLING WAS REPL...
# 1463   RETD TO ARPT AFTER REPORTING A BIRDSTRIKE SHOR...
# 2095   FLT 657 RETD TO LAND AFTER A BIRD STRIKE. BOTH...
# 3351   FLEW THRU A FLOCK. NO STRIKES NOTED. POST FLT ...
# 3436   CREW NOTICED AN UNUSUAL VIBRATION IN ONE ENG. ...
# ...                                                  ...
# 24377  ID BY SMITHSONIAN. PORT AUTH RECVD A CALL FROM...
# 24446  NUMEROUS STRIKES ON NOSE AND INSIDE BOTH ENGIN...
# ...

# %%
filtered_dfnan = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'].isnull()]
filtered_dfnan
# Out:
#                             Airport: Name Altitude bin Aircraft: Make/Model  \
# 33     EGLIN AFB/NW FLORIDA REGIONAL ARPT    < 1000 ft                F-15E
# 196         BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 237         BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 348         BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 354         BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# ...                                   ...          ...                  ...
# 24704                 JOHN F KENNEDY INTL    < 1000 ft              CRJ-440
# 24726      FORT LAUDERDALE EXECUTIVE ARPT    < 1000 ft            PA-31-350
# 24776                  HONOLULU INTL ARPT    < 1000 ft               F/A-18
# 25086    KALAELOA ARPT JOHN RODGERS FIELD    < 1000 ft                DA-40
# 25126                ELLINGTON FIELD ARPT    < 1000 ft                T-38A
#
# ...

# %%
filtered_engine_nan_percent = filtered_df_nan_engines[['Aircraft: Number of engines?', 'Remarks']]
filtered_engine_nan_percent
# Out:
#        Aircraft: Number of engines?  \
# 3387                            NaN
# 14909                           NaN
#
#                                                  Remarks
# 3387   Large bird ingested down left engine.  Severe ...
# 14909  ID BY SMITHSONIAN, FAA 2606. 100% DNA MATCH. O...

# %%
birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'B-52H']
# Out:
#                       Airport: Name Altitude bin Aircraft: Make/Model  \
# 196   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 237   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 348   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 354   BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# 1277  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 1321  BARKSDALE AIR FORCE BASE ARPT    > 1000 ft                B-52H
# 1333  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 1521  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 1539  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 1569  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 1593  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# 1594  BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                B-52H
# ...

# %%
# Filter the DataFrame for rows where 'Aircraft: Make/Model' is 'B-52H'
b52h_rows = birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'B-52H']

# Fill NaN values in the 'Aircraft: Number of engines?' column for the filtered rows with the specified value (e.g., 8)
b52h_rows['Aircraft: Number of engines?'].fillna(8, inplace=True)

# Assign the filled values back to the original DataFrame using loc
birdspecies_filter.loc[birdspecies_filter['Aircraft: Make/Model'] == 'B-52H', 'Aircraft: Number of engines?'] = b52h_rows['Aircraft: Number of engines?']

# Display the updated DataFrame
print(birdspecies_filter)
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                       KANSAS CITY INTL    < 1000 ft                MD-80
# 1      CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft          CITATION II
# 2                             MIAMI INTL    > 1000 ft              DA-2000
# 3            SOUTHWEST FLORIDA INTL ARPT    < 1000 ft           HAWKER 800
# 4                         NASHVILLE INTL    < 1000 ft            B-737-400
# ...                                  ...          ...                  ...
# 25198                       ORLANDO INTL    < 1000 ft                A-321
# 25199                  REDDING MUNICIPAL    > 1000 ft              EMB-120
# 25200    DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft            B-757-200
# 25201       GEORGE BUSH INTERCONTINENTAL    < 1000 ft              EMB-145
# 25202       ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft            B-737-400
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
birdspecies_filter.isnull().sum()
# Out:
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                197
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4752
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# ...

# %%
birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'T-38A']
# Out:
#                        Airport: Name Altitude bin Aircraft: Make/Model  \
# 556          SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 1388         SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 1403         SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 1460         SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 1461         SHEPPARD AIR FORCE BASE    > 1000 ft                T-38A
# 1562         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 1757         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 2009   BARKSDALE AIR FORCE BASE ARPT    < 1000 ft                T-38A
# 2335         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 2467         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 2468         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# 2725         SHEPPARD AIR FORCE BASE    < 1000 ft                T-38A
# ...

# %%
filtered_df_nan_engines
# Out:
#                           Airport: Name Altitude bin  Aircraft: Make/Model  \
# 10167            LONG ISLAND MAC ARTHUR    < 1000 ft     AMD ALARUS CH2000
# 11414                 LINCOLN MUNICIPAL    < 1000 ft               CRJ-440
# 13036       LORAIN COUNTY REGIONAL ARPT    < 1000 ft          MISC - OTHER
# 15633              GROTON-NEW LONDON AR    < 1000 ft           ECLIPSE 500
# 16197               JOE FOSS FIELD ARPT    < 1000 ft  CITATION MUSTANG 510
# 17446            NEVADA COUNTY AIR PARK    < 1000 ft   GRUMMAN S-2 TRACKER
# 18228           WESTCHESTER COUNTY ARPT    < 1000 ft                BD-700
# 23568                KLAMATH FALLS INTL    < 1000 ft             B-787-800
# 24580  CAPE COD COAST GUARD AIR STATION    < 1000 ft                 HU-25
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 10167                       1                               1
# 11414                       1                               1
# ...

# %%
t38a_rows = birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'T-38A']

# Fill NaN values in the 'Aircraft: Number of engines?' column for the filtered rows with the specified value (e.g., 8)
t38a_rows['Aircraft: Number of engines?'].fillna(2, inplace=True)

# Assign the filled values back to the original DataFrame using loc
birdspecies_filter.loc[birdspecies_filter['Aircraft: Make/Model'] == 'T-38A', 'Aircraft: Number of engines?'] = t38a_rows['Aircraft: Number of engines?']

# Display the updated DataFrame
print(birdspecies_filter)
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                       KANSAS CITY INTL    < 1000 ft                MD-80
# 1      CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft          CITATION II
# 2                             MIAMI INTL    > 1000 ft              DA-2000
# 3            SOUTHWEST FLORIDA INTL ARPT    < 1000 ft           HAWKER 800
# 4                         NASHVILLE INTL    < 1000 ft            B-737-400
# ...                                  ...          ...                  ...
# 25198                       ORLANDO INTL    < 1000 ft                A-321
# 25199                  REDDING MUNICIPAL    > 1000 ft              EMB-120
# 25200    DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft            B-757-200
# 25201       GEORGE BUSH INTERCONTINENTAL    < 1000 ft              EMB-145
# 25202       ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft            B-737-400
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
birdspecies_filter.isnull().sum()
# Out:
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                169
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4752
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# ...

# %%
birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'CRJ-440']
# Out:
#                          Airport: Name Altitude bin Aircraft: Make/Model  \
# 9804   DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 9983   DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 10153  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 10204                     MEMPHIS INTL    < 1000 ft              CRJ-440
# 10205  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# ...                                ...          ...                  ...
# 20857        OUTAGAMIE COUNTY REGIONAL    < 1000 ft              CRJ-440
# 21233  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 23020  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft              CRJ-440
# 23770                   QUAD CITY ARPT    < 1000 ft              CRJ-440
# 24704              JOHN F KENNEDY INTL    < 1000 ft              CRJ-440
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
filtered_df_nan_engines
# Out:
#                           Airport: Name Altitude bin  Aircraft: Make/Model  \
# 10167            LONG ISLAND MAC ARTHUR    < 1000 ft     AMD ALARUS CH2000
# 11414                 LINCOLN MUNICIPAL    < 1000 ft               CRJ-440
# 13036       LORAIN COUNTY REGIONAL ARPT    < 1000 ft          MISC - OTHER
# 15633              GROTON-NEW LONDON AR    < 1000 ft           ECLIPSE 500
# 16197               JOE FOSS FIELD ARPT    < 1000 ft  CITATION MUSTANG 510
# 17446            NEVADA COUNTY AIR PARK    < 1000 ft   GRUMMAN S-2 TRACKER
# 18228           WESTCHESTER COUNTY ARPT    < 1000 ft                BD-700
# 23568                KLAMATH FALLS INTL    < 1000 ft             B-787-800
# 24580  CAPE COD COAST GUARD AIR STATION    < 1000 ft                 HU-25
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 10167                       1                               1
# 11414                       1                               1
# ...

# %%
birdspecies_filter['Effect: Indicated Damage'].unique()
# Out:
# array(['No damage', 'Caused damage'], dtype=object)

# %%
filtered_df1 = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'] == 1]
filtered_df2 = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'] == 2]
filtered_df3 = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'] == 3]
filtered_df4 = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'] == 4]
filtered_dfnan = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'].isnull()]



filtered_df_effect1 = filtered_df1[filtered_df1['Effect: Indicated Damage'] == 'Caused damage'] 
filtered_df_effect2 = filtered_df2[filtered_df2['Effect: Indicated Damage'] == 'Caused damage']
filtered_df_effect3 = filtered_df3[filtered_df3['Effect: Indicated Damage'] == 'Caused damage']
filtered_df_effect4 = filtered_df4[filtered_df4['Effect: Indicated Damage'] == 'Caused damage']
filtered_df_effectnan = filtered_dfnan[filtered_dfnan['Effect: Indicated Damage'] == 'Caused damage']

filtered_df_engine1 = filtered_df_effect1[filtered_df_effect1['Remarks'].str.contains('eng', case=False, na=False)]
filtered_df_engine2 = filtered_df_effect2[filtered_df_effect2['Remarks'].str.contains('eng', case=False, na=False)]
filtered_df_engine3 = filtered_df_effect3[filtered_df_effect3['Remarks'].str.contains('eng', case=False, na=False)]
filtered_df_engine4 = filtered_df_effect4[filtered_df_effect4['Remarks'].str.contains('eng', case=False, na=False)]
filtered_df_nan_engines = filtered_df_effectnan[filtered_df_effectnan['Remarks'].str.contains('eng', case=False, na=False)]
# Step 2: Optionally, select specific columns of interest
# result = filtered_df[['Column1', 'Column2']]  # replace 'Column1' and 'Column2' with actual column names

# Display the filtered result
filtered_engine1_percent = filtered_df_engine1[['Aircraft: Number of engines?', 'Remarks']].shape[0]
filtered_engine2_percent = filtered_df_engine2[['Aircraft: Number of engines?', 'Remarks']].shape[0]
filtered_engine3_percent = filtered_df_engine3[['Aircraft: Number of engines?', 'Remarks']].shape[0]
filtered_engine4_percent = filtered_df_engine4[['Aircraft: Number of engines?', 'Remarks']].shape[0]
filtered_engine_nan_percent = filtered_df_nan_engines[['Aircraft: Number of engines?', 'Remarks']].shape[0]

total_percent_remarks = birdspecies_filter['Remarks'].shape[0]

print(f"Percentage of wildlife struck with aircraft having only one engine:{(filtered_engine1_percent/total_percent_remarks)*100:.2f}%")
print(f"Percentage of wildlife struck with aircraft having only two engines:{(filtered_engine2_percent/total_percent_remarks)*100:.2f}%") 
print(f"Percentage of wildlife struck with aircraft having only three engines:{(filtered_engine3_percent/total_percent_remarks)*100:.2f}%")
print(f"Percentage of wildlife struck with aircraft having only four engines:{(filtered_engine4_percent/total_percent_remarks)*100:.2f}%")        
print(f"Percentage of wildlife struck with aircraft having only nan values:{(filtered_engine_nan_percent/total_percent_remarks)*100:.2f}%")
# Out:
# Percentage of wildlife struck with aircraft having only one engine:0.07%
# Percentage of wildlife struck with aircraft having only two engines:2.51%
# Percentage of wildlife struck with aircraft having only three engines:0.07%
# Percentage of wildlife struck with aircraft having only four engines:0.08%
# Percentage of wildlife struck with aircraft having only nan values:0.00%

# %%
crj440_rows = birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'CRJ-440']

# Fill NaN values in the 'Aircraft: Number of engines?' column for the filtered rows with the specified value (e.g., 8)
crj440_rows['Aircraft: Number of engines?'].fillna(2, inplace=True)

# Assign the filled values back to the original DataFrame using loc
birdspecies_filter.loc[birdspecies_filter['Aircraft: Make/Model'] == 'CRJ-440', 'Aircraft: Number of engines?'] = crj440_rows['Aircraft: Number of engines?']

# Display the updated DataFrame
print(birdspecies_filter)
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                       KANSAS CITY INTL    < 1000 ft                MD-80
# 1      CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft          CITATION II
# 2                             MIAMI INTL    > 1000 ft              DA-2000
# 3            SOUTHWEST FLORIDA INTL ARPT    < 1000 ft           HAWKER 800
# 4                         NASHVILLE INTL    < 1000 ft            B-737-400
# ...                                  ...          ...                  ...
# 25198                       ORLANDO INTL    < 1000 ft                A-321
# 25199                  REDDING MUNICIPAL    > 1000 ft              EMB-120
# 25200    DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft            B-757-200
# 25201       GEORGE BUSH INTERCONTINENTAL    < 1000 ft              EMB-145
# 25202       ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft            B-737-400
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
birdspecies_filter.isnull().sum()
# Out:
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                 95
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4752
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# ...

# %%
birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'CITATION MUSTANG 510']
# Out:
#              Airport: Name Altitude bin  Aircraft: Make/Model  \
# 16197  JOE FOSS FIELD ARPT    < 1000 ft  CITATION MUSTANG 510
# 18239        HOUSTON-HOBBY    < 1000 ft  CITATION MUSTANG 510
# 20427  OAKLAND COUNTY INTL    < 1000 ft  CITATION MUSTANG 510
# 20492        BOB HOPE ARPT    < 1000 ft  CITATION MUSTANG 510
# 20895  HAGERSTOWN REGIONAL    < 1000 ft  CITATION MUSTANG 510
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 16197                 2 to 10                               4
# 18239                       1                               1
# 20427                       1                               1
# 20492                       1                               1
# 20895                       1                               1
#
#       Effect: Impact to flight FlightDate Effect: Indicated Damage  \
# 16197    Precautionary Landing  3/10/2009            Caused damage
# 18239                     None  9/17/2009                No damage
# ...

# %%
citationmustang510_rows = birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'CITATION MUSTANG 510']

# Fill NaN values in the 'Aircraft: Number of engines?' column for the filtered rows with the specified value (e.g., 8)
citationmustang510_rows['Aircraft: Number of engines?'].fillna(2, inplace=True)

# Assign the filled values back to the original DataFrame using loc
birdspecies_filter.loc[birdspecies_filter['Aircraft: Make/Model'] == 'CITATION MUSTANG 510', 'Aircraft: Number of engines?'] = citationmustang510_rows['Aircraft: Number of engines?']

# Display the updated DataFrame
print(birdspecies_filter)
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                       KANSAS CITY INTL    < 1000 ft                MD-80
# 1      CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft          CITATION II
# 2                             MIAMI INTL    > 1000 ft              DA-2000
# 3            SOUTHWEST FLORIDA INTL ARPT    < 1000 ft           HAWKER 800
# 4                         NASHVILLE INTL    < 1000 ft            B-737-400
# ...                                  ...          ...                  ...
# 25198                       ORLANDO INTL    < 1000 ft                A-321
# 25199                  REDDING MUNICIPAL    > 1000 ft              EMB-120
# 25200    DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft            B-757-200
# 25201       GEORGE BUSH INTERCONTINENTAL    < 1000 ft              EMB-145
# 25202       ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft            B-737-400
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'GRUMMAN S-2 TRACKER']
# Out:
#                 Airport: Name Altitude bin Aircraft: Make/Model  \
# 17446  NEVADA COUNTY AIR PARK    < 1000 ft  GRUMMAN S-2 TRACKER
# 23556    UKIAH MUNICIPAL ARPT    < 1000 ft  GRUMMAN S-2 TRACKER
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 17446                       1                               1
# 23556                       1                               1
#
#       Effect: Impact to flight FlightDate Effect: Indicated Damage  \
# 17446                     None  7/25/2009            Caused damage
# 23556                     None  7/22/2011                No damage
#
#        Aircraft: Number of engines? Aircraft: Airline/Operator  ...  \
# 17446                           NaN                   BUSINESS  ...
# 23556                           NaN                 GOVERNMENT  ...
#
#       Remains of wildlife sent to Smithsonian  \
# 17446                                   False
# 23556                                   False
#
# ...

# %%
grummans2tracker_rows = birdspecies_filter[birdspecies_filter['Aircraft: Make/Model'] == 'GRUMMAN S-2 TRACKER']

# Fill NaN values in the 'Aircraft: Number of engines?' column for the filtered rows with the specified value (e.g., 8)
grummans2tracker_rows['Aircraft: Number of engines?'].fillna(2, inplace=True)

# Assign the filled values back to the original DataFrame using loc
birdspecies_filter.loc[birdspecies_filter['Aircraft: Make/Model'] == 'GRUMMAN S-2 TRACKER', 'Aircraft: Number of engines?'] = grummans2tracker_rows['Aircraft: Number of engines?']

# Display the updated DataFrame
print(birdspecies_filter)
# Out:
#                            Airport: Name Altitude bin Aircraft: Make/Model  \
# 0                       KANSAS CITY INTL    < 1000 ft                MD-80
# 1      CINCINNATI MUNI ARPT-LUNKEN FIELD    < 1000 ft          CITATION II
# 2                             MIAMI INTL    > 1000 ft              DA-2000
# 3            SOUTHWEST FLORIDA INTL ARPT    < 1000 ft           HAWKER 800
# 4                         NASHVILLE INTL    < 1000 ft            B-737-400
# ...                                  ...          ...                  ...
# 25198                       ORLANDO INTL    < 1000 ft                A-321
# 25199                  REDDING MUNICIPAL    > 1000 ft              EMB-120
# 25200    DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft            B-757-200
# 25201       GEORGE BUSH INTERCONTINENTAL    < 1000 ft              EMB-145
# 25202       ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft            B-737-400
#
#       Wildlife: Number struck  Wildlife: Number Struck Actual  \
# ...

# %%
# Assuming your DataFrame is named birdspecies_filter

# Step 1: Filter the DataFrame for rows where 'Number of Engines' column has NaN values
nan_engine_rows = birdspecies_filter[birdspecies_filter['Aircraft: Number of engines?'].isnull()]

# Step 2: Display the 'Aircraft Model' column for the filtered rows
print(nan_engine_rows['Aircraft: Make/Model'])
# Out:
# 33           F-15E
# 374        KC-135R
# 451          C-17A
# 582         AT-38B
# 598         AT-38B
#            ...
# 24333         T-38
# 24580        HU-25
# 24726    PA-31-350
# 24776       F/A-18
# 25086        DA-40
# Name: Aircraft: Make/Model, Length: 93, dtype: object

# %%
nan_engine_rows['Aircraft: Make/Model'].value_counts()
# Out:
# C-17A                 15
# AT-38B                 8
# PA-31-350              6
# ECLIPSE 500            5
# A-10A                  5
# CESSNA UNKN            4
# BD-700                 4
# KC-135R                4
# T-38                   4
# HOMEBUILT              3
# HU-25                  3
# SA227 DC METRO 23      2
# C-21A                  2
# HAWKER 900             2
# B-737-600              2
# HC-130                 1
# F-15E                  1
# T-38N                  1
# CRJ-900                1
# FLIGHT DESIGN CTSW     1
# CL-RJ705               1
# B-787-800              1
# F/A-18                 1
# LOCKHEED P3A           1
# AMD ALARUS CH2000      1
# CESSNA LC-41           1
# MISC - OTHER           1
# CL-215                 1
# CANADAIR               1
# E-8C                   1
# F-15C                  1
# T-1A                   1
# F-16D                  1
# F-16C                  1
# B-1B                   1
# C-130E                 1
# MC-130H                1
# ...

# %%
birdspecies_filter.to_csv(r'D:\UM internship\Bird Strike\birdstrike_filterspecies_new.csv')
