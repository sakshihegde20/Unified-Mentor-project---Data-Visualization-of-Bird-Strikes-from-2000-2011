# %%
import pandas as pd
import numpy as np

# %%
URL = r"D:\UM internship\Bird Strike\birdnew.csv"

birdstrike_new = pd.read_csv(URL)

# %%
birdstrike_new[birdstrike_new['Aircraft: Make/Model'] == 'C-680']
# Out:
#        Unnamed: 0                   Airport: Name Altitude bin  \
# 2969         2971                  DUPAGE AIRPORT    > 1000 ft
# 3444         3446       MORRISTOWN MUNICIPAL ARPT    < 1000 ft
# 3540         3542               RICKENBACKER INTL    < 1000 ft
# 3666         3668            ADDINGTON FIELD ARPT    < 1000 ft
# 4292         4296             OAKLAND COUNTY INTL    < 1000 ft
# 13814       13844        CHICAGO MIDWAY INTL ARPT    < 1000 ft
# 14726       14758        MINNEAPOLIS-ST PAUL INTL    < 1000 ft
# 14918       14950               TETERBORO AIRPORT    < 1000 ft
# 15631       15668               TETERBORO AIRPORT    < 1000 ft
# 16001       16040        CHICAGO O'HARE INTL ARPT    < 1000 ft
# 16457       16501             RALEIGH-DURHAM INTL    > 1000 ft
# 16501       16546               TETERBORO AIRPORT    < 1000 ft
# 16502       16547                   CHINO AIRPORT    < 1000 ft
# 16922       16968       MORRISTOWN MUNICIPAL ARPT    < 1000 ft
# ...

# %%
selected_rows = [2969,3444, 3540, 3666, 4292, 13814, 14726, 14918,15631, 16001, 21427, 21520]
selected_column = 'Aircraft: Number of engines?'

subset = birdstrike_new.loc[selected_rows, selected_column]

filled_data = subset.bfill()

# %%
filled_data
# Out:
# 2969     2
# 3444     2
# 3540     2
# 3666     2
# 4292     2
# 13814    2
# 14726    2
# 14918    2
# 15631    2
# 16001    2
# 21427    2
# 21520    2
# Name: Aircraft: Number of engines?, dtype: object

# %%
birdstrike_new.loc[selected_rows, selected_column] = filled_data

# %%
birdstrike_new.isnull().sum()
# Out:
# Unnamed: 0                                    0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                227
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4761
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# ...

# %%
birdstrike_new[birdstrike_new['Aircraft: Number of engines?'] == 'C']
# Out:
#       Unnamed: 0              Airport: Name Altitude bin Aircraft: Make/Model  \
# 6652        6664  MORGANTOWN MUNICIPAL ARPT    > 1000 ft         RKWLTRBO 690
#
#      Wildlife: Number struck  Wildlife: Number Struck Actual  \
# 6652                       1                               1
#
#      Effect: Impact to flight  FlightDate Effect: Indicated Damage  \
# 6652                     None  2001-11-05                No damage
#
#      Aircraft: Number of engines?  ...  \
# 6652                            C  ...
#
#      Remains of wildlife sent to Smithsonian  \
# 6652                                   False
#
#                                                 Remarks Wildlife: Size  \
# 6652  PILOT ADZ NO DMG. INFO RELAYED TO CKB THRU MGW...         Medium
#
#      Conditions: Sky      Wildlife: Species  \
# 6652        No Cloud  Unknown bird - medium
#
#       Pilot warned of birds or wildlife? Cost: Total $ Feet above ground  \
# ...

# %%
birdstrike_new.at[6652,'Aircraft: Number of engines?'] = 2

# %%
birdstrike_new['Aircraft: Number of engines?'].unique()
# Out:
# array(['2', '3', '4', nan, '1', 2], dtype=object)

# %%
birdstrike_new[birdstrike_new['Aircraft: Make/Model'] == 'B-747-8 SERIES']
# Out:
#        Unnamed: 0               Airport: Name Altitude bin  \
# 3574         3576  COLORADO SPRINGS MUNICIPAL    < 1000 ft
# 23032       23124        BOEING FIELD K C INT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 3574        B-747-8 SERIES                 2 to 10
# 23032       B-747-8 SERIES                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  FlightDate  \
# 3574                                4                     None  2010-08-21
# 23032                               1                     None  2011-01-03
#
#       Effect: Indicated Damage Aircraft: Number of engines?  ...  \
# 3574                 No damage                            4  ...
# 23032            Caused damage                          NaN  ...
#
#       Remains of wildlife sent to Smithsonian  \
# 3574                                    False
# 23032                                    True
#
# ...

# %%
birdstrike_new.at[23032, 'Aircraft: Number of engines?'] = 4

# %%
birdstrike_new[birdstrike_new['Aircraft: Make/Model'] == 'B-747-8 SERIES']
# Out:
#        Unnamed: 0               Airport: Name Altitude bin  \
# 3574         3576  COLORADO SPRINGS MUNICIPAL    < 1000 ft
# 23032       23124        BOEING FIELD K C INT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 3574        B-747-8 SERIES                 2 to 10
# 23032       B-747-8 SERIES                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  FlightDate  \
# 3574                                4                     None  2010-08-21
# 23032                               1                     None  2011-01-03
#
#       Effect: Indicated Damage Aircraft: Number of engines?  ...  \
# 3574                 No damage                            4  ...
# 23032            Caused damage                            4  ...
#
#       Remains of wildlife sent to Smithsonian  \
# 3574                                    False
# 23032                                    True
#
# ...

# %%
birdstrike_new.to_csv(r'D:\UM internship\Bird Strike\birdnew.csv')
